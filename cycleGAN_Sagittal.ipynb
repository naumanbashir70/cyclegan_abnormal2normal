# %%
# !git clone https://github.com/LynnHo/CycleGAN-Tensorflow-2

# %%
# %cd /content/drive/MyDrive/CycleGAN_Sagittal/CycleGAN-Tensorflow-2
# Out:
# /content/drive/MyDrive/CycleGAN_Sagittal/CycleGAN-Tensorflow-2

# %%
# !unzip 'datasets.zip'

# %%
# !pip install  tensorflow_addons
# Out:
# ...
#      |████████████████████████████████| 686kB 8.2MB/s
# ...

# %%
# !pip install oyaml

# %%
# !python3 train.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Inner Epoch Loop:  50% 169/340 [01:43<01:44,  1.64it/s]
# Inner Epoch Loop:  50% 170/340 [01:43<01:43,  1.64it/s]
# Inner Epoch Loop:  50% 171/340 [01:44<01:43,  1.64it/s]
# Inner Epoch Loop:  51% 172/340 [01:45<01:42,  1.64it/s]
# Inner Epoch Loop:  51% 173/340 [01:45<01:41,  1.64it/s]
# Inner Epoch Loop:  51% 174/340 [01:46<01:41,  1.64it/s]
# Inner Epoch Loop:  51% 175/340 [01:46<01:40,  1.64it/s]
# Inner Epoch Loop:  52% 176/340 [01:47<01:39,  1.65it/s]
# Inner Epoch Loop:  52% 177/340 [01:48<01:38,  1.65it/s]
# Inner Epoch Loop:  52% 178/340 [01:48<01:38,  1.64it/s]
# Inner Epoch Loop:  53% 179/340 [01:49<01:38,  1.64it/s]
# Inner Epoch Loop:  53% 180/340 [01:49<01:37,  1.64it/s]
# Inner Epoch Loop:  53% 181/340 [01:50<01:36,  1.64it/s]
# Inner Epoch Loop:  54% 182/340 [01:51<01:36,  1.64it/s]
# Inner Epoch Loop:  54% 183/340 [01:51<01:35,  1.64it/s]
# Inner Epoch Loop:  54% 184/340 [01:52<01:35,  1.64it/s]
# ...

# %%
# !python3 train.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Inner Epoch Loop:  47% 159/340 [01:36<01:49,  1.66it/s]
# Inner Epoch Loop:  47% 160/340 [01:36<01:48,  1.66it/s]
# Inner Epoch Loop:  47% 161/340 [01:37<01:47,  1.66it/s]
# Inner Epoch Loop:  48% 162/340 [01:38<01:47,  1.66it/s]
# Inner Epoch Loop:  48% 163/340 [01:38<01:46,  1.66it/s]
# Inner Epoch Loop:  48% 164/340 [01:39<01:46,  1.66it/s]
# Inner Epoch Loop:  49% 165/340 [01:39<01:45,  1.66it/s]
# Inner Epoch Loop:  49% 166/340 [01:40<01:44,  1.66it/s]
# Inner Epoch Loop:  49% 167/340 [01:41<01:44,  1.66it/s]
# Inner Epoch Loop:  49% 168/340 [01:41<01:43,  1.66it/s]
# Inner Epoch Loop:  50% 169/340 [01:42<01:43,  1.66it/s]
# Inner Epoch Loop:  50% 170/340 [01:42<01:42,  1.66it/s]
# Inner Epoch Loop:  50% 171/340 [01:43<01:41,  1.66it/s]
# Inner Epoch Loop:  51% 172/340 [01:44<01:41,  1.66it/s]
# Inner Epoch Loop:  51% 173/340 [01:44<01:40,  1.66it/s]
# Inner Epoch Loop:  51% 174/340 [01:45<01:40,  1.66it/s]
# ...
